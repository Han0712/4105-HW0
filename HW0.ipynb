# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/Han/Downloads/D3.csv')
df.head()
M = len(df)

# %%
#x is the first column of the data, the input for this variable will be changed as we use the second and third colume of data set.
x1 = df.values[:, 0]
x2 = df.values[:, 1]
x3 = df.values[:, 2]

#y is the fourth column and it will be the dependent variable
y = df.values[:, 3]
m = len(y)

# %%
#plot the x vs. y scatter graph
plt.scatter(x1, y, color='red', marker='+')
plt.grid()
plt.rcParams["figure.figsize"] = (15,10)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot of training data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data')

# %%
#reshaping x variable in to a 2-D array
x_0 = np.ones((m, 1))
x_0[: 5]
x_1 = x1.reshape(m, 1)
x_1 [: 10]
x = np.hstack((x_0, x_1))
x[: 5]
# Out:
# array([[1.        , 0.04040404],
#        [1.        , 0.08080808],
#        [1.        , 0.12121212],
#        [1.        , 0.16161616],
#        [1.        , 0.2020202 ]])

# %%
#intialize theata to 0
theta = np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
#formulas for computing cost
def compute_cost(x,y,theta):
    """
    Compute cost for linear regression.
    
    Input Parameters
    x : 2D array where each row represent the training example and each column represent
        m= number of training examples
        n= number of features
    y : 1D array of labels/target value for each traing example. dimension(1 x m)
    
    theta : 1D array of fitting parameters or weights. Dimension (1 x n)
    
    Output Parameters 
    J : Scalar value. 
    """
    predictions = x.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    
    return J

# %%
cost = compute_cost(x, y, theta)
print('The cost for given values of theta_0 and theta_1 =', cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.483015861682611

# %%
#formulas for computing gradient descent 
def gradient_descent(x, y, theta, alpha, iterations):
    """
    Compute cost for linear regression.
    
    Input Parameters
    x : 2D array where each row represent the training example and each column represent
        m= number of training examples
        n= number of features (including x_0 column of ones)
    y : 1D array of labels/target value for each traing example. dimension(1 x m)
    theta : 1D array of fitting parameters or weights. Dimension (1 x n)
    alpha : Learning rate. Scalar value  
    iterations: No of iterations. Scalar value. 
    
    Output Parameters
    theta : Final Value. 1D array of fitting parameters or weights. Dimension (1 x n)  
    cost_history: Conatins value of cost for each iteration. 1D array. Dimansion(m x 1)
    """
    cost_history=np.zeros(iterations)
    
    for i in range(iterations):
        predictions = x.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * x.transpose().dot(errors);
        theta = theta - sum_delta;
        cost_history[i] = compute_cost(x, y, theta)
        
    return theta, cost_history

# %%
theta = [0., 0]
#number of iterations
iterations = 1500;
#alpha is the learning rate, and for the first colume a learning rate of 0.02 seems to be the best
alpha = 0.02;

# %%
theta, cost_history = gradient_descent(x, y, theta, alpha, iterations)
print('Final value of theta =', theta)
print('cost_history =', cost_history)
# Out:
# Final value of theta = [ 5.98195664 -2.05834603]
# cost_history = [5.40171893 5.33104394 5.26859135 ... 0.98247745 0.98247736 0.98247727]

# %%
#plotting the scatter plot with a Linear regression line
plt.scatter(x[:, 1], y, color = 'red', marker = '+', label = 'Training Data')
plt.plot(x[:, 1], x.dot(theta), color = 'green', label = 'Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('x1')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()

# %%
#plotting of the cost vs iteration
plt.plot(range(1, iterations + 1), cost_history, color='blue')
plt.rcParams["figure.figsize"] = (15,10)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
plt.scatter(x[:, 1], y, color = 'red', marker = '+', label = 'Training Data')
plt.plot(x[:, 1], x.dot(theta), color = 'green', label = 'Linear Regression')

plt.rcParams["figure.figsize"] = (10,6)
plt.grid()
plt.xlabel('x1')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()

# %%
x1 = df.values[:, 0]
x2 = df.values[:, 1]
x3 = df.values[:, 2]
y = df.values[:, 3]

X_0 = x1
X_1 = x2
X_2 = x3
def fourDTheta():
    X0 = np.ones((m,1))
    X1 = x1.reshape(m,1)
    X2 = x2.reshape(m,1)
    X3 = x3.reshape(m,1)
    X_3 = np.hstack((X0, X1, X2, X3))

    theta = np.zeros(4)
    iterations = 1500;
    alpha = 0.1;
    
    cost = compute_cost(X_3,y,theta)
    theta, cost_history = gradient_descent(X_3,y,theta,alpha,iterations)
    
    return theta, cost_history

# %%
theta, cost_history = fourDTheta()
theta
# Out:
# array([ 5.41374693, -2.04203017,  0.56122181, -0.2921286 ])

# %%
plt.plot(range(1, iterations + 1), cost_history, color='yellow')
plt.rcParams["figure.figsize"] = (15,10)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
df = pd.read_csv('/Users/Han/Downloads/D3.csv')
df.head()
M = len(df)

# %%
Prediciton = theta[0] + (1)*theta[1] + (1)*theta[2] + (1)*theta[3]
Prediciton
# Out:
# 3.6408099791685866

# %%
Prediciton = theta[0] + (2)*theta[1] + (0)*theta[2] + (4)*theta[3]
Prediciton
# Out:
# 0.16117220225655737

# %%
Prediciton = theta[0] + (3)*theta[1] + (2)*theta[2] + (1)*theta[3]
Prediciton
# Out:
# 0.1179714561932278
